# %%
from threading import Thread, Lock
import time
import random

queue = []
lock = Lock()

class ProducerThread(Thread):
    def run(self):
        nums = range(10) #Will create the list [0, 1, 2, 3, 4]
        global queue
        while True:
            num = random.choice(nums) #Selects a random number from list [0, 1, 2, 3, 4]
            lock.acquire()
            queue.append(num)
            print ("Produced", num)
            lock.release()
            time.sleep(random.random())


class ConsumerThread(Thread):
    def run(self):
        global queue
        while True:
            lock.acquire()
            if not queue:
                print ("Nothing in queue, but consumer will try to consume")
            num = queue.pop(0)
            print ("Consumed", num)
            lock.release()
            time.sleep(random.random())


ProducerThread().start()
ConsumerThread().start()
# Out:
# Produced 0
# Consumed 0
# Produced 8
# Consumed 8
# Produced 5
# Produced 3
# Consumed 5
# Produced 5
# Consumed 3
# Produced 6
# Consumed 5
# Produced 2
# Produced 1
# Consumed 6
# Produced 0
# Consumed 2
# Consumed 1
# Produced 8
# Consumed 0
# Produced 0
# Consumed 8
# Produced 1
# Consumed 0
# Produced 1
# Produced 3
# Consumed 1
# Consumed 1
# Produced 4
# Produced 2
# Produced 3
# Consumed 3
# Produced 2
# Consumed 4
# Consumed 2
# Consumed 3
# Consumed 2
# Produced 0
# Produced 0
# Consumed 0
# Produced 3
# Consumed 0
# Produced 2
# Produced 9
# Consumed 3
# Produced 9
# Consumed 2
# Produced 0
# Produced 2
# Consumed 9
# Produced 5
# Consumed 9
# Consumed 0
# Consumed 2
# Produced 0
# Produced 9
# Consumed 5
# Consumed 0
# Consumed 9
# Produced 9
# Produced 9
# Consumed 9
# Produced 1
# Produced 5
# Consumed 9
# Produced 7
# Consumed 1
# Produced 5
# Produced 1
# Produced 4
# Consumed 5
# Consumed 7
# Produced 0
# Consumed 5
# Produced 0
# Consumed 1
# Consumed 4
# Produced 0
# Consumed 0
# Produced 0
# Consumed 0
# Produced 1
# Consumed 0
# Produced 8
# Produced 3
# Consumed 0
# Consumed 1
# Consumed 8
# Consumed 3
# Produced 0
# Produced 2
# Consumed 0
# Consumed 2
# Produced 0
# Consumed 0
# Produced 2
# Consumed 2
# Exception in thread Thread-20:
# Traceback (most recent call last):
#   File "R:\Anaconda\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Lenovo\AppData\Local\Temp\ipykernel_3504\2840230517.py", line 28, in run
# IndexError: pop from empty list
# Nothing in queue, but consumer will try to consume
