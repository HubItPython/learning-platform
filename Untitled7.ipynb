# %%
from selenium import webdriver

# Create Edge options to start Edge minimized
options = webdriver.EdgeOptions()
options.add_argument("--start-minimized")
options.add_argument("inprivate")
options.add_argument("headless")

# Initialize the Edge WebDriver with minimized options
driver = webdriver.Edge(options=options)

# Your web automation code here

driver.get("https://www.youtube.com")

# %%
import tkinter as tk
import cv2
import PIL.Image
import PIL.ImageTk
import yt_dlp
import threading

# Function to load and play the YouTube video
def play_video():
    try:
        video_url = url_entry.get()
        ydl_opts = {
            'format': 'best',
        }
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            info_dict = ydl.extract_info(video_url, download=False)
            video_url = info_dict.get("url")

        cap = cv2.VideoCapture(video_url)
        
        def update_frame():
            ret, frame = cap.read()
            if ret:
                frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                img = PIL.Image.fromarray(frame)
                img = PIL.ImageTk.PhotoImage(image=img)
                canvas.create_image(0, 0, anchor=tk.NW, image=img)
                canvas.img = img
                root.after(10, update_frame)
        
        update_frame()
    except Exception as e:
        print(f"An error occurred: {str(e)}")

# Create the main Tkinter window
root = tk.Tk()
root.title("YouTube Video Player")
root.geometry("800x600")

# Create an Entry widget for entering the YouTube URL
url_entry = tk.Entry(root, width=50)
url_entry.pack(pady=10)
url_entry.insert(0, "Enter YouTube Video URL")

# Create a button to load and play the video
play_button = tk.Button(root, text="Play Video", command=play_video)
play_button.pack(pady=10)

# Create a canvas to display the video
canvas = tk.Canvas(root, width=640, height=480)
canvas.pack()

# Start the Tkinter main loop
def run():
    root.mainloop()

if __name__ == '__main__':
    run()

# %%
import tkinter as tk
import cv2
import PIL.Image
import PIL.ImageTk
import yt_dlp
import threading
import pygame

# Initialize pygame mixer
pygame.mixer.init()

def play_video():
    try:
        video_url = url_entry.get()
        ydl_opts = {
            'format': 'best[ext=mp4]',
        }
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            info_dict = ydl.extract_info(video_url, download=False)
            video_url = info_dict.get("url")

        cap = cv2.VideoCapture(video_url)

        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

        # Create a new tkinter window
        video_window = tk.Toplevel(root)
        video_window.title("YouTube Video Player")

        # Create a canvas to display the video
        canvas = tk.Canvas(video_window, width=width, height=height)
        canvas.pack()

        def update():
            ret, frame = cap.read()
            if not ret:
                cap.release()
                video_window.destroy()
            else:
                frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                img = PIL.Image.fromarray(frame)
                img = PIL.ImageTk.PhotoImage(image=img)
                canvas.create_image(0, 0, anchor=tk.NW, image=img)
                canvas.img = img
                video_window.after(10, update)

        update()
    except Exception as e:
        print(f"An error occurred: {str(e)}")

def play_audio():
    try:
        audio_url = url_entry.get()
        ydl_opts = {
            'format': 'bestaudio/best',
        }
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            info_dict = ydl.extract_info(audio_url, download=False)
            audio_url = info_dict.get("url")

        pygame.mixer.music.load(audio_url)
        pygame.mixer.music.play()

    except Exception as e:
        print(f"An error occurred: {str(e)}")

def threads_play_video():
    st = threading.Thread(target=play_video)
    st.start()

def threads_play_audio():
    st = threading.Thread(target=play_audio)
    st.start()

root = tk.Tk()
root.title("YouTube Media Player")
root.geometry("800x600")

url_entry = tk.Entry(root, width=50)
url_entry.pack(pady=10)
url_entry.insert(0, "Enter YouTube Video/Audio URL")

play_video_button = tk.Button(root, text="Play Video", command=threads_play_video)
play_video_button.pack(pady=10)

play_audio_button = tk.Button(root, text="Play Audio", command=threads_play_audio)
play_audio_button.pack(pady=10)

def run():
    root.mainloop()

if __name__ == '__main__':
    run()

# %%
pip install yt-dlp pydub

# %%
import tkinter as tk
import cv2
import PIL.Image
import PIL.ImageTk
from pytube import YouTube
import threading
import pygame

# Initialize pygame mixer
pygame.mixer.init()

def play_video():
    try:
        video_url = url_entry.get()
        ydl_opts = {
            'format': 'best[ext=mp4]',
        }
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            info_dict = ydl.extract_info(video_url, download=False)
            video_url = info_dict.get("url")

        cap = cv2.VideoCapture(video_url)

        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

        # Create a new tkinter window
        video_window = tk.Toplevel(root)
        video_window.title("YouTube Video Player")

        # Create a canvas to display the video
        canvas = tk.Canvas(video_window, width=width, height=height)
        canvas.pack()

        def update():
            ret, frame = cap.read()
            if not ret:
                cap.release()
                video_window.destroy()
            else:
                frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                img = PIL.Image.fromarray(frame)
                img = PIL.ImageTk.PhotoImage(image=img)
                canvas.create_image(0, 0, anchor=tk.NW, image=img)
                canvas.img = img
                video_window.after(10, update)

        update()
    except Exception as e:
        print(f"An error occurred: {str(e)}")

def play_audio():
    try:
        audio_url = url_entry.get()
        yt = YouTube(audio_url)
        audio_stream = yt.streams.filter(only_audio=True).first()
        audio_file_path = audio_stream.download()
        pygame.mixer.music.load(audio_file_path)
        pygame.mixer.music.play()

    except Exception as e:
        print(f"An error occurred: {str(e)}")

def threads_play_video():
    st = threading.Thread(target=play_video)
    st.start()

def threads_play_audio():
    st = threading.Thread(target=play_audio)
    st.start()

root = tk.Tk()
root.title("YouTube Media Player")
root.geometry("800x600")

url_entry = tk.Entry(root, width=50)
url_entry.pack(pady=10)
url_entry.insert(0, "Enter YouTube Video/Audio URL")

play_video_button = tk.Button(root, text="Play Video", command=threads_play_video)
play_video_button.pack(pady=10)

play_audio_button = tk.Button(root, text="Play Audio", command=threads_play_audio)
play_audio_button.pack(pady=10)

def run():
    root.mainloop()

if __name__ == '__main__':
    run()

# %%
import youtube_dl
import time
from tkinter import *
from tkinter.ttk import Progressbar
from tkinter import font as tkFont

#application to download youtube song's with or without video
#pretty slow but took a lot of work
#application looks like it's freezing during the downloading process. this is normal.


#name tk function "window" and give it a cool title.
window = Tk()
window.title("SUPER AWESOME YOUTUBE DOWNLOADER V1")


#create window size, xy method
window.geometry('575x400')

#setup useless progress bar (makes sense later)
progress = Progressbar(window, orient=HORIZONTAL,
                       length=250, mode='determinate')
#make background red
window.configure(bg='red')

def A_option():

    #download song
    #retrieve input

    vid = entry1.get()

    #to only get audio you need specific inputs in ytlib library. no idea why this works, but i got it from the web.
    #used a try statement because program can be buggy sometimes. this way it will work nonetheless.
    #outtmpl is for the download's destination, not sure if this means the code has to change on other computers...


    try:
        ytlib = {
            'format': 'bestaudio/best',
            'noplaylist': True,
            'outtmpl': '/python_downloads/%(title)s-%(id)s.%(ext)s',
            'continue_dl': True,
            'postprocessors_args': [{
                'key': 'FFmpegExtractAudio',
                'preferredcodec': 'wav',
                'preferredquality': 'max'}]
        }

    except Exception:
        print('something went wrong...')

    with youtube_dl.YoutubeDL(ytlib) as ydl:

        ydl.download([vid])
        print("download complete")

    bar()
    window.mainloop()


def bar():

    #progress bar
    #couldn't manage to make it show the actual downloading process...
    #looks pretty neat so i'm keeping it

    progress['value'] = 20
    window.update_idletasks()
    time.sleep(1)

    progress['value'] = 40
    window.update_idletasks()
    time.sleep(1)

    progress['value'] = 50
    window.update_idletasks()
    time.sleep(1)

    progress['value'] = 60
    window.update_idletasks()
    time.sleep(1)

    progress['value'] = 80
    window.update_idletasks()
    time.sleep(1)
    progress['value'] = 100

    window.mainloop()

def B_option():

    #download video
    #only had to put outtmpl here because it downloads video's automatically

    vid = entry1.get()

    ytlib = {
        'outtmpl': '/python_downloads/%(title)s-%(id)s.%(ext)s'
    }

    with youtube_dl.YoutubeDL(ytlib) as ydl:

        ydl.download([vid])
        print("download complete")

    bar()
    window.mainloop()

def delete():
    #clears input window (didn't go automatic because i suck)
    entry1.delete(0, 'end')

def stop():
    #imidiatly terminates process
    print('Program finished')
    quit()


def setup():

    #here comes the sloppy part

    #font size
    foptions = tkFont.Font(family='Helvetica', size=15, weight=tkFont.NORMAL)

    #create a collum
    #determine distance inbetween rows of buttons and stuff
    window.columnconfigure(index=0, weight=0)
    window.rowconfigure(index=0, weight=0)

    #create label to point to input box
    #row is how far down the item is, column is how far right.
    elink = Label(window, text='Enter youtube link below:', font=foptions, bg='red')
    elink.grid(row=0, column=0, columnspan=2)

    #get youtube link input here
    #make the entry field global, because that makes sense?
    global entry1
    entry1 = Entry(window, width=50, font=foptions, bg='red', fg='black')
    entry1.grid(row=1, column=0, columnspan=2)

    #empty progress bar. does not really do anything usefull but looks cool and took a lot of effort.
    #tried to apply it to the actual progress, but i'm not that good....
    #idk what "pady" does, but internet said to do so and it works.
    the_lie = Label(window, text='Completing download:', font=foptions, bg='red')
    the_lie.grid(row=4, column=0, columnspan=2)
    progress.grid(row=5, column=0, columnspan=2, pady=10)


    #buttons to the options of the app with some modifications to look slightly less bad.
    Button(window, text='download song', font=foptions, width=15, height=5, bg='black', fg='red', command=A_option).grid(row=2, column=0)
    Button(window, text='download video', font=foptions, width=15, height=5, bg='black', fg='red', command=B_option).grid(row=2, column=1)
    Button(window, text='clear entry', font=foptions, width=15, height=5, bg='black', fg='red', command=delete).grid(row=3, column=0)
    Button(window, text='exit', font=foptions, width=15, height=5, bg='black', fg='red', command=stop).grid(row=3, column=1)

    #always use them mainloops
    window.mainloop()

setup()

# %%
import tkinter as tk
import cv2
import PIL.Image
import PIL.ImageTk
import yt_dlp
import threading
import pygame

# Initialize pygame mixer
pygame.mixer.init()

def play_video():
    try:
        video_url = url_entry.get()
        ydl_opts = {
            'format': 'best[ext=mp4]',
        }
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            info_dict = ydl.extract_info(video_url, download=False)
            video_url = info_dict.get("url")

        cap = cv2.VideoCapture(video_url)

        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)

        # Create a new tkinter window
        video_window = tk.Toplevel(root)
        video_window.title("YouTube Video Player")

        # Create a canvas to display the video
        canvas = tk.Canvas(video_window, width=width, height=height)
        canvas.pack()

        def update():
            ret, frame = cap.read()
            if not ret:
                cap.release()
                video_window.destroy()
            else:
                frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                img = PIL.Image.fromarray(frame)
                img = PIL.ImageTk.PhotoImage(image=img)
                canvas.create_image(0, 0, anchor=tk.NW, image=img)
                canvas.img = img
                video_window.after(10, update)

        update()
    except Exception as e:
        print(f"An error occurred: {str(e)}")

def play_audio():
    try:
        audio_url = url_entry.get()
        ydl_opts = {
            'format': 'bestaudio/best',
        }
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            info_dict = ydl.extract_info(audio_url, download=False)
            audio_url = info_dict.get("url")

        pygame.mixer.music.load(audio_url)
        pygame.mixer.music.play()

    except Exception as e:
        print(f"An error occurred: {str(e)}")

def threads_play_video():
    st = threading.Thread(target=play_video)
    st.start()

def threads_play_audio():
    st = threading.Thread(target=play_audio)
    st.start()

root = tk.Tk()
root.title("YouTube Media Player")
root.geometry("800x600")

url_entry = tk.Entry(root, width=50)
url_entry.pack(pady=10)
url_entry.insert(0, "Enter YouTube Video URL")

play_video_button = tk.Button(root, text="Play Video", command=threads_play_video)
play_video_button.pack(pady=10)

play_audio_button = tk.Button(root, text="Play Audio", command=threads_play_audio)
play_audio_button.pack(pady=10)

def run():
    root.mainloop()

if __name__ == '__main__':
    run()

# %%
import tkinter as tk
from tkinter import ttk
from tkinterweb import WebView

def play_youtube_video():
    video_url = url_entry.get()
    webview.create_window("YouTube Video Player", video_url, width=800, height=600)

root = tk.Tk()
root.title("YouTube Video Player")
root.geometry("800x600")

url_entry = ttk.Entry(root, width=50)
url_entry.pack(pady=10)
url_entry.insert(0, "https://www.youtube.com/embed/3wkPgFrM36o")  # Replace VIDEO_ID with the actual video ID

play_button = ttk.Button(root, text="Play Video", command=play_youtube_video)
play_button.pack(pady=10)

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 3
#       1 import tkinter as tk
#       2 from tkinter import ttk
# ----> 3 from tkinterweb import WebView
#       5 def play_youtube_video():
#       6     video_url = url_entry.get()
#
# ImportError: cannot import name 'WebView' from 'tkinterweb' (C:\Users\Ramesh\AppData\Roaming\Python\Python311\site-packages\tkinterweb\__init__.py)

# %%
import yt_dlp

# Create a yt-dlp instance
ydl = yt_dlp.YoutubeDL()

# Specify the download options
ydl_opts = {
    'format': 'bestvideo[ext=mp4]+bestaudio[ext=m4a]/best[ext=mp4]',  # To download the best mp4 format
    'outtmpl': 'downloads/%(title)s.%(ext)s',  # Output template for file naming
}

# URL of the YouTube video you want to download
video_url = 'https://www.youtube.com/watch?v=3wkPgFrM36o'  # Replace YOUR_VIDEO_ID with the actual video ID

# Download the video
with ydl:
    result = ydl.extract_info(video_url, download=True)
    if 'entries' in result:
        video = result['entries'][0]
    else:
        video = result

print(f"Downloaded: {video['title']} in mp4 format")
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=3wkPgFrM36o
# [youtube] 3wkPgFrM36o: Downloading webpage
# [youtube] 3wkPgFrM36o: Downloading ios player API JSON
# [youtube] 3wkPgFrM36o: Downloading android player API JSON
# [youtube] 3wkPgFrM36o: Downloading m3u8 information
# [info] 3wkPgFrM36o: Downloading 1 format(s): 616+251
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 60
# [download] Destination: Tose Naina Tum Jo Aaye l T-Series Mixtape l Armaan Malik Tulsi Kumar l Bhushan Kumar Ahmed Abhijit [3wkPgFrM36o].f616.mp4
# [download] 100% of  123.53MiB in 00:02:09 at 980.33KiB/s
# [download] Destination: Tose Naina Tum Jo Aaye l T-Series Mixtape l Armaan Malik Tulsi Kumar l Bhushan Kumar Ahmed Abhijit [3wkPgFrM36o].f251.webm
# [download] 100% of    5.07MiB in 00:00:01 at 4.77MiB/s
# [Merger] Merging formats into "Tose Naina Tum Jo Aaye l T-Series Mixtape l Armaan Malik Tulsi Kumar l Bhushan Kumar Ahmed Abhijit [3wkPgFrM36o].webm"
# ...
