# %%
from tkinter import *
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from pytube import YouTube
from PIL import Image, ImageTk
import threading
from yt_dlp import YoutubeDL
import os
from tkinter import filedialog
from moviepy.editor import VideoFileClip
import sys
import io
import webbrowser



# Directory where you want to save the audio file
output_directory = "C:/Users/Ramesh/Downloads"

# Create options for yt-dlp
ydl_opts = {
    'format': 'bestaudio/best',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',  # You can change the output format here
        'preferredquality': '192',  # Adjust the audio quality as needed
    }],
    'outtmpl': output_directory + '%(title)s.%(ext)s',  # Save the file with its actual name
}

# Initialize the YoutubeDL object with options
ydl = YoutubeDL(ydl_opts)

# Download and convert the video to audio
with ydl:
    result = ydl.extract_info("https://www.youtube.com/watch?v=-PshNjguh_4", download=True)
#         time.sleep(20)
print("Completed")

# %%
import tkinter as tk
from tkinter import Entry, Button
from PIL import Image, ImageTk
import requests
from io import BytesIO

# Function to load and display the YouTube video's thumbnail
def display_thumbnail():
    video_url = url_entry.get()


    try:
        # Construct the thumbnail URL
        thumbnail_url = f"https://img.youtube.com/vi/{video_url.split('=')[-1]}/maxresdefault.jpg"
        
        # Fetch the image from the URL
        response = requests.get(thumbnail_url)
        img_data = BytesIO(response.content)
        
        # Open the image using Pillow (PIL)
        thumbnail = Image.open(img_data)
        
        # Resize the image to fit the display
        thumbnail = thumbnail.resize((200, 200))

        # Convert to PhotoImage format for Tkinter
        thumbnail_image = ImageTk.PhotoImage(thumbnail)

        thumbnail_label.config(image=thumbnail_image)
        thumbnail_label.image = thumbnail_image
    except Exception as e:
        print(f"An error occurred: {str(e)}")

# Create the main application window
root = tk.Tk()
root.title("YouTube Thumbnail Viewer")

# Create an Entry for the user to enter the YouTube URL
url_label = tk.Label(root, text="Enter YouTube URL:")
url_label.pack()
url_entry = Entry(root, width=40)
url_entry.pack()

# Create a button to display the thumbnail
display_button = Button(root, text="Display Thumbnail", command=display_thumbnail)
display_button.pack()

# Create a label to display the thumbnail image
thumbnail_label = tk.Label(root)
thumbnail_label.pack()

root.mainloop()

# %%
filename = url.split("/")[-1]
filename=filename.split("?")[0]
response = request.get(url)
response.raise_for_status()
directory = filedialog.askdirectory(initialdir=os.path.expanduser("~"), title="Select Directory")

if directory:
    filepath= os.path.join(directory,f"{filename}_{quality}.jpg")
    with open(filepath,"wb") as file:
        file.write(response.content)
    print(f"Thumbnail saved at {filepath})

# %%
from tkinter import *
from yt_dlp import YoutubeDL

# Directory where you want to save the audio file
output_directory = "C:/Users/Ramesh/Downloads/"

# Create options for yt-dlp
ydl_opts = {
    'format': 'bestaudio/best',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',  # You can change the output format here
        'preferredquality': '192',  # Adjust the audio quality as needed
    }],
    'outtmpl': output_directory + '%(title)s.%(ext)s',  # Save the file with its actual name
}

# Initialize the YoutubeDL object with options
ydl = YoutubeDL(ydl_opts)

# Download and convert the video to audio
with ydl:
    result = ydl.extract_info("https://www.youtube.com/watch?v=-PshNjguh_4", download=True)

print("Completed")

# %%
import tkinter as tk
import pyperclip
import webbrowser

def play_youtube_video():
    video_url = "https://www.youtube.com/watch?v=VAdGW7QDJiU"
    
    # Copy the YouTube video URL to the clipboard
    pyperclip.copy(video_url)
    
    # Open a web browser component within tkinter to display the video
    web_browser = tk.Toplevel(root)
    web_browser.geometry("800x600")
    
    browser = tk.Text(web_browser)
    browser.pack(fill="both", expand=True)
    
    browser.insert("1.0", "Loading YouTube video...")
    
    # Wait for a short delay to allow the clipboard to be recognized
    root.after(1000, lambda: browser.insert("1.0", video_url))
    
root = tk.Tk()
root.geometry("800x600")

play_button = tk.Button(root, text="Play YouTube Video", command=play_youtube_video)
play_button.pack()

root.mainloop()

# %%
import asyncio
from playwright import async_playwright

async def perform_web_automation():
    async with async_playwright() as p:
        browser = await p.chromium.launch()
        context = await browser.new_context()
        page = await context.new_page()

        # Navigate to a URL
        await page.goto("https://playwright.dev")

        # Your automation code here

        # Close the browser when done
        await browser.close()

# Run the async function using an event loop
asyncio.run(perform_web_automation())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 2
#       1 import asyncio
# ----> 2 from playwright import async_playwright
#       4 async def perform_web_automation():
#       5     async with async_playwright() as p:
#
# ImportError: cannot import name 'async_playwright' from 'playwright' (C:\Users\Ramesh\AppData\Roaming\Python\Python311\site-packages\playwright\__init__.py)

# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


#Working................................

from tkinter import *
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from pytube import YouTube
from PIL import Image, ImageTk
import threading
from yt_dlp import YoutubeDL
import os
from tkinter import filedialog
from moviepy.editor import VideoFileClip
import sys
import io
import webbrowser
import requests
from io import BytesIO
from tkinter import messagebox


def choose_file():
    file_path = filedialog.askopenfilename(filetypes=[("MP4 files", "*.mp4",)])
    if file_path:
        title_entry.delete(0, END)
        title_entry.insert(0, file_path)









def convert_to_mp3():
    input_file = title_entry.get()
    if input_file:
        output_file = input_file.replace(".mp4", ".mp3")
        try:
            title_label.config(r, height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
                  text="Converting").place(x=850, y=310)
            video = VideoFileClip(input_file)
            title_label.config(r, height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
                  text="1").place(x=850, y=310)
            audio = video.audio
            title_label.config(r, height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
                  text="2").place(x=850, y=310)
            audio.write_audiofile(output_file, codec='mp3')
            
            title_label.config(r, height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
                  text="Conversion Completed").place(x=850, y=310)
        except Exception as e:
            title_label.config(r, height=2, width=100, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
                  text=f"An error occurred: {str(e)}").place(x=450, y=310)

def custom_url_audio_thread():
    # Directory where you want to save the audio file
    download_dir = filedialog.askdirectory()
    initial_files = set(os.listdir(download_dir))
    title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Mp3 Downloading")   
    system_download_folder = os.path.expanduser('~')  # This points to the user's home directory
    system_download_folder = os.path.join(system_download_folder, download_dir)

    # Define the output directory and filename template
    output_template = os.path.join(download_dir, '%(title)s.%(ext)s')
# Create options for yt-dlp
    ydl_opts = {
    'format': 'bestaudio/best',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',  # You can change the output format here
        'preferredquality': '192',  # Adjust the audio quality as needed
    }],
    'outtmpl': output_template  # Save the file with its actual name
}

# Initialize the YoutubeDL object with options
    ydl = YoutubeDL(ydl_opts)

# Download and convert the video to audio
    with ydl:
        result = ydl.extract_info(custom_url, download=True)
        # Wait for the download to complete
    timeout_seconds = 50000000  # Adjust this as needed
    start_time = time.time()

    while time.time() - start_time < timeout_seconds:
        current_files = set(os.listdir(download_dir))
        new_files = current_files - initial_files

        if new_files:
            title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Download Completed")
            audio_url_button.destroy()
            path = os.path.realpath(download_dir)
            os.startfile(path)
            break
        elif output_template:
            title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="File is already Downloaded")
            audio_url_button.destroy()
            break
        else:
            title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Downloading....")
            time.sleep(5)

    if time.time() - start_time >= timeout_seconds:
        title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Download didn't complete within the specified timeout.")
         

def custom_url_video_thread():
#     try:
        
        download_dir = filedialog.askdirectory()
        initial_files = set(os.listdir(download_dir))
        title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Video Downloading")   
        system_download_folder = os.path.expanduser('~')  # This points to the user's home directory
        system_download_folder = os.path.join(system_download_folder, download_dir)

    # Define the output directory and filename template
        output_template = os.path.join(download_dir, '%(title)s.%(ext)s')

    # Create options for yt-dlp
        ydl_opts = {
        'outtmpl': output_template,
    }

    # Initialize the YoutubeDL object with options
        ydl = YoutubeDL(ydl_opts)

    # Download the video
        with ydl:
            result = ydl.extract_info(custom_url, download=True)
    

    # Wait for the download to complete
        timeout_seconds = 50000000  # Adjust this as needed
        start_time = time.time()

        while time.time() - start_time < timeout_seconds:
            current_files = set(os.listdir(download_dir))
            new_files = current_files - initial_files

            if new_files:
                title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Download Completed")
                video_url_button.destroy()
                path = os.path.realpath(download_dir)
                os.startfile(path)
                break
            elif output_template:
                title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="File is already Downloaded")
                video_url_button.destroy()
                break
            else:
                title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Downloading....")
                time.sleep(5)

        if time.time() - start_time >= timeout_seconds:
            title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Download didn't complete within the specified timeout.")
         

        if time.time() - start_time >= timeout_seconds:
            title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Download didn't complete within the specified timeout.")
            
def audio():
    # Directory where you want to save the audio file
    output_dir = "C:/Users/Ramesh/Downloads/"
    initial_files = set(os.listdir(output_dir))
    title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
                  text="Mp3 Downloading")
    output_template = os.path.join(output_dir, '%(title)s.%(ext)s')
# Create options for yt-dlp
    ydl_opts = {
    'format': 'bestaudio/best',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',  # You can change the output format here
        'preferredquality': '192',  # Adjust the audio quality as needed
    }],
    'outtmpl': output_template   # Save the file with its actual name
}

# Initialize the YoutubeDL object with options
    ydl = YoutubeDL(ydl_opts)

# Download and convert the video to audio
    with ydl:
        result = ydl.extract_info(current_url, download=True)
    title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Download Completed")
    # Wait for the download to complete
    system_download_folder = os.path.expanduser('~')  # This points to the user's home directory
    system_download_folder = os.path.join(system_download_folder, output_dir)
    timeout_seconds = 50000000  # Adjust this as needed
    start_time = time.time()

    while time.time() - start_time < timeout_seconds:
        current_files = set(os.listdir(output_dir))
        new_files = current_files - initial_files

        if new_files:
            title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Download Completed")
            audio_button.destroy()        
            path = os.path.realpath(output_dir)
            os.startfile(path)
            break
        elif output_template:
            title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="File is already Downloaded")
            path = os.path.realpath(output_dir)
            os.startfile(path)
            audio_button.destroy()   
            break
        else:
            title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Downloading....")
            time.sleep(5)

    if time.time() - start_time >= timeout_seconds:
        title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Download didn't complete within the specified timeout.")
    

def convert_to_mp3():
    try:
        title = title_entry.get()
        title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Download Started")

    # Create Chrome options for headless mode
        chrome_options = webdriver.ChromeOptions()
        chrome_options.add_argument("--headless")

    # Initialize the Chrome WebDriver with headless options
        driver = webdriver.Chrome(options=chrome_options)
        
        title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Processing")

    # Website
        driver.get("https://www.youtube.com/")
        title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="On the way")

    # Search input box
        search_input = driver.find_element("name", "search_query")
        search_input.send_keys(f"{title}")

        time.sleep(2)
        title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Ready")

    # Search button
        search_button = driver.find_element(By.XPATH, "//*[@id='search-icon-legacy']")
        search_button.click()
        time.sleep(3)
        title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Steady")

    # Select the first video from the searched list
        video_title = driver.find_element(By.XPATH, "//*[@id='video-title']/yt-formatted-string")
        video_title.click()

    # Get the current URL (video URL)
        current_url = driver.current_url
        title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Go")
        driver.quit()

# Replace 'your_youtube_video_url' with the actual YouTube video URL


# Directory where you want to save the audio file
        output_directory = filedialog.askdirectory()

# Create options for yt-dlp
        ydl_opts = {
    'format': 'bestaudio/best',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',  # You can change the output format here
        'preferredquality': '192',  # Adjust the audio quality as needed
    }],
    'outtmpl': output_directory + '%(title)s.%(ext)s',  # Save the file with its actual name
}

# Initialize the YoutubeDL object with options
        ydl = YoutubeDL(ydl_opts)

# Download and convert the video to audio
        with ydl:
            result = ydl.extract_info(current_url, download=True)
            title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
                  text="Mp3 downloaded")
        
    except Exception as e:
        title_label.config(height=2, width=100, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
                  text=f"An error occurred: {str(e)}")

def dummy():
    messagebox.showinfo("Warning","Click on Text or URL button")
def facebook():
    webbrowser.open("https://www.facebook.com/gangeshwar.kumar.3517")

def url_video():      #url download thread 
    try:
        global custom_url
        custom_url = title_entry.get()
        thumbnail_label = Label(r)
        # Construct the thumbnail URL
        thumbnail_url = f"https://img.youtube.com/vi/{custom_url.split('=')[-1]}/maxresdefault.jpg"
        
        # Fetch the image from the URL
        response = requests.get(thumbnail_url)
        img_data = BytesIO(response.content)
        
        # Open the image using Pillow (PIL)
        thumbnail = Image.open(img_data)
        
        # Resize the image to fit the display
        thumbnail = thumbnail.resize((300, 300))

        # Convert to PhotoImage format for Tkinter
        thumbnail_image = ImageTk.PhotoImage(thumbnail)

        thumbnail_label.config(image=thumbnail_image)
        thumbnail_label.image = thumbnail_image
        thumbnail_label.place(x=100,y=50)
        video_url_button.place(x=890, y=465)          #video button
        audio_url_button.place(x=950, y=465)          #audio button

    except Exception as e:
        title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text=f"An error occurred: {str(e)}")



# Create a function to handle the download process
def title_video():      #title download thread

        title = title_entry.get()
        title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Searching Your Video")

    # Create Chrome options for headless mode
        chrome_options = webdriver.ChromeOptions()
        chrome_options.add_argument("--headless")

#     # Initialize the Chrome WebDriver with headless options
        driver = webdriver.Chrome()
        chrome_options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.6045.105 Safari/537.36")

# # Set custom headers
#         chrome_options.add_argument("headers=your-custom-headers")
#         driver = webdriver.Chrome(options=chrome_options)

        
        title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Processing")

    # Website
        driver.get("https://www.youtube.com/")
    # Search input box
        search_input = driver.find_element("name", "search_query")
        search_input.send_keys(f"{title}")

        time.sleep(2)
        title_label.config( height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Ready")
        
    # Search button
        search_button = driver.find_element(By.XPATH, "//*[@id='search-icon-legacy']")
        search_button.click()
#         time.sleep(3)
        driver.implicitly_wait(8)
        title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Steady")

    # Select the first video from the searched list    
        video_title = driver.find_element(By.XPATH, "//*[@id='video-title']/yt-formatted-string")
        video_title.click()
        
        title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Internet Connection Failed")
            
    # Get the current URL (video URL)
        global current_url
        current_url = driver.current_url
        driver.quit()
        
        title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Go")
        try:
            thumbnail_label = Label(r)
        # Construct the thumbnail URL
            thumbnail_url = f"https://img.youtube.com/vi/{current_url.split('=')[-1]}/maxresdefault.jpg"
        
        # Fetch the image from the URL
            response = requests.get(thumbnail_url)
            img_data = BytesIO(response.content)
        
        # Open the image using Pillow (PIL)
            thumbnail = Image.open(img_data)
        
        # Resize the image to fit the display
            thumbnail = thumbnail.resize((300, 300))

        # Convert to PhotoImage format for Tkinter
            thumbnail_image = ImageTk.PhotoImage(thumbnail)

            thumbnail_label.config(image=thumbnail_image)
            thumbnail_label.image = thumbnail_image
            thumbnail_label.place(x=100,y=50)
        except Exception as e:
            print(f"An error occurred: {str(e)}")
        video_button.place(x=890, y=465)          #video button
        audio_button.place(x=950, y=465)          #audio button

def video():
    try:
        
        download_dir = filedialog.askdirectory()
        initial_files = set(os.listdir(download_dir))
        title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Downloading")   
        system_download_folder = os.path.expanduser('~')  # This points to the user's home directory
        system_download_folder = os.path.join(system_download_folder, download_dir)

    # Define the output directory and filename template
        output_template = os.path.join(download_dir, '%(title)s.%(ext)s')

    # Create options for yt-dlp
        ydl_opts = {
        'outtmpl': output_template,
    }

    # Initialize the YoutubeDL object with options
        ydl = YoutubeDL(ydl_opts)

    # Download the video
        with ydl:
            result = ydl.extract_info(current_url, download=True)
    

    # Wait for the download to complete
        timeout_seconds = 50000000  # Adjust this as needed
        start_time = time.time()

        while time.time() - start_time < timeout_seconds:
            current_files = set(os.listdir(download_dir))
            new_files = current_files - initial_files

            if new_files:
                title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Download Completed")
                video_button.destroy()
                path = os.path.realpath(download_dir)
                os.startfile(path)
                break
            elif output_template:
                title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="File is already Downloaded")
                video_button.destroy()
                break
            else:
                title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Downloading....")
                time.sleep(5)

        if time.time() - start_time >= timeout_seconds:
            title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text="Download didn't complete within the specified timeout.")
         
    except Exception as e:
        title_label.config(height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c",
          text=f"video {str(e)}")

def url_download_button():
        download_button = Button(r, text="URL_Download", cursor="hand2",bg="#10a197", 
                                 borderwidth=6, activebackground="#40a6ac", height=3, width=14, command=url_download)
        download_button.place(x=890, y=510)

def title_download_button():
        download_button = Button(r, text="Title_Download", cursor="hand2",bg="#10a197", 
                                 borderwidth=6, activebackground="#40a6ac", height=3, width=14, command=title_download)
        download_button.place(x=890, y=510)   

# Create the main application window
r = Tk()
r.attributes('-fullscreen', True)

############################################
# THREADS
def title_download():
    download_thread = threading.Thread(target=title_video)
    download_thread.start()

def url_download():
    download_thread = threading.Thread(target=url_video)
    download_thread.start()

def profile():
    download_thread = threading.Thread(target=facebook)
    download_thread.start()

    
def select_file():
    select_thread = threading.Thread(target=choose_file)
    select_thread.start()
    
def convert():
    converter_thread= threading.Thread(target=convert_to_mp3)
    converter_thread.start()
    
def video_file():
    video_thread= threading.Thread(target=video)
    video_thread.start()
    
def audio_file():
    audio_thread= threading.Thread(target=audio)
    audio_thread.start()
# custom_url_audio
def custom_url_audio():
    custom_url_audios= threading.Thread(target=custom_url_audio_thread)
    custom_url_audios.start()
def custom_url_video():
    custom_url_videos= threading.Thread(target=custom_url_video_thread)
    custom_url_videos.start()
#########################################################
def exit_full_screen(event):
    r.attributes('-fullscreen', False)
    r.geometry("1366x768")


r.bind('<Escape>', exit_full_screen)
r.title("Youtube Downloader")

# Load the background image
bg_image = Image.open("images/youtube_bg.jpg")
bg_photo = ImageTk.PhotoImage(bg_image)

# Create a Canvas widget to display the image
canvas = Canvas(r, width=1366, height=768)
canvas.pack()

# Place the image on the Canvas
canvas.create_image(0, 0, image=bg_photo, anchor=NW)

# Y text
Label(r, text="Y", font=("Gill Sans", 60, "bold"), bg="#0B0301", fg="RED",highlightthickness=0).place(x=872, y=200)

#outube text
Label(r, text="outube", font=("Helvetica", 38, "bold"), bg="#0B0301", fg="#c21717",highlightthickness=0).place(x=925, y=220)



# Create a title_label.config with text "Enter Title"
global title_label
title_label = Label(r, height=2, width=25, highlightthickness=10, font=("Helvetica", 15, "bold"), bg="#8c356c", text="Enter Title:")
title_label.place(x=850, y=310) 

#Input Field
title_entry = Entry(r)
title_entry.place(height=45, width=310, x=858, y=420)
title_entry.config(highlightbackground="#963109", font=("Helvetica", 15, "bold"), highlightthickness=4, borderwidth=3)

# Create a button to start the download process
title_button = Button(r, text="Title", cursor="hand2",bg="#10a197",
                      activebackground="#40a6ac", height=1, width=5, command=title_download_button)
title_button.place(x=867, y=394)

url_button = Button(r, text="Url", cursor="hand2",bg="#10a197", 
                    activebackground="#40a6ac", height=1, width=5, command=url_download_button)
url_button.place(x=913, y=394)

#Dummy Button
dummy_button = Button(r, text="Click Title Or URL", cursor="hand2",bg="#10a197", 
                                 borderwidth=6, activebackground="#40a6ac", height=3, width=14, command=dummy)
dummy_button.place(x=890, y=510)

#Close button
button = Button(r, text="Close", bg="#a3dfad",cursor="hand2", borderwidth=6,
                activebackground="#40a6ac", height=3, width=14, command=r.destroy)
button.place(x=1035, y=510)

youtube_icon_image = Image.open("images/youtube_icon.jpg")
youtube_icon_image = youtube_icon_image.resize((38, 38))
youtube_icon_photo = ImageTk.PhotoImage(youtube_icon_image)
youtube_icon_button = Button(r, image=youtube_icon_photo)
youtube_icon_button.place(x=844, y=528)

video_button = Button(r, text="Video", bg="#22d1d4", cursor="hand2",
                       borderwidth=6, activebackground="#40a6ac", height=1, width=5, command=video_file)


audio_button = Button(r, text="Audio", bg="#22d1d4", cursor="hand2",
                       borderwidth=6, activebackground="#40a6ac", height=1, width=5, command=audio_file)

audio_url_button = Button(r, text="Audio", bg="#22d1d4", cursor="hand2",
                       borderwidth=6, activebackground="#40a6ac", height=1, width=5, command=custom_url_audio)
video_url_button = Button(r, text="Video", bg="#22d1d4", cursor="hand2",
                       borderwidth=6, activebackground="#40a6ac", height=1, width=5, command=custom_url_video)

#Select button

select_button = Button(r, text="Select File", bg="#22d1d4", cursor="hand2",
                       borderwidth=6, activebackground="#40a6ac", height=3, width=14, command=select_file)
select_button.place(x=890, y=580)

profile_button = Button(r, text="Developer: Gangeshwar Lohar", bg="#22d1d4",cursor="hand2",
                        borderwidth=6, activebackground="#40a6ac", height=1, width=25, command=profile)
profile_button.place(x=1150, y=730)

#Convert Button

convert_button = Button(r, text="Convert To Mp3",cursor="hand2", bg="#961478",
                        borderwidth=6, activebackground="#40a6ac", height=3, width=14, command=convert)
convert_button.place(x=1035, y=580)


mainloop()
